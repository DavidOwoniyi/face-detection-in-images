# %% [markdown]
# # Face Detection in images

# %% [markdown]
# ### This simple program detects faces in images using Python, OpenCV, numpy and matplotlib. Steps are as follows.

# %% [markdown]
# ### Import libraries

# %%
import cv2 as cv
import numpy as np
import requests
import matplotlib.pyplot as plt

# %% [markdown]
# ### URL of the hosted image

# %%
# url = "https://lh3.googleusercontent.com/d/1SazmxZvko0PO8DiDQtodRHHoMl50UJyv"
imagePath = "img.JPG"

# %% [markdown]
# ### Download the image

# %%
# response = requests.get(url)
# img_array = np.array(bytearray(response.content), dtype=np.uint8).

# %% [markdown]
# ### Convert image to OpenCV format

# %%
# img = cv.imdecode(img_array, -1)
img = cv.imread(imagePath)

# %% [markdown]
# ### Convert image to grayscale

# %%
gray_image = cv.cvtColor(img, cv.COLOR_BGR2GRAY)

# %% [markdown]
# ### Load the Classifier

# %%
face_classifier = cv.CascadeClassifier(
    cv.data.haarcascades + "haarcascade_frontalface_default.xml"
)

# %% [markdown]
# ### Perform face detection

# %%
face = face_classifier.detectMultiScale(
    gray_image, scaleFactor=1.1, minNeighbors=7, minSize=(40, 40)
)

# %% [markdown]
# ### Drawing a bounding circle

# %%
for (x, y, w, h) in face:
    cv.circle(img, (x + w // 2, y + h // 2), (w // 2), (0, 255, 255), 2)

# %% [markdown]
# ### Displaying the image

# %%
img_rgb = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.figure(figsize=(10, 10))
plt.imshow(img_rgb)
plt.axis('off')
# plt.savefig("guy2.png", bbox_inches='tight')
# Out:
# (-0.5, 4159.5, 6239.5, -0.5)
